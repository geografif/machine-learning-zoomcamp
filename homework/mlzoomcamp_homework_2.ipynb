# %%
import os
os.getcwd()
# Out:
# 'D:\\Learn'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
pip install wget
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=ff025f4f430256b72b168028c6d92ef8628471a2426a6148c8db408d017ebe49
#   Stored in directory: c:\users\fauzan\appdata\local\pip\cache\wheels\40\b3\0f\a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# ...

# %%
import wget
# !python -m wget "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv"
# Out:
# Saved under housing.csv

# %%
df = pd.read_csv('housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#pd.read_csv(<file_path_string>) - read csv files
#df.head() - take a look of the dataframe
#df.columns - retrieve colum names of a dataframe
#df.columns.str.lower() - lowercase all the letters
#df.columns.str.replace(' ', '_') - replace the space separator
#df.dtypes - retrieve data types of all features
#df.index - retrieve indices of a dataframe

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#change entry to lowercase and replace space with underscore

df.columns = df.columns.str.lower().str.replace(' ', '_')
string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
print(df.ocean_proximity.unique())
# Out:
# ['near_bay' '<1h_ocean' 'inland' 'near_ocean' 'island']

# %%
#new_df = df[df['ocean_proximity'] == ''

df = df[(df['ocean_proximity'] == '<1h_ocean') | (df['ocean_proximity'] == 'inland')]

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 701      -121.97     37.64                32.0       1283.0           194.0
# 830      -121.99     37.61                 9.0       3666.0           711.0
# 859      -121.97     37.57                21.0       4342.0           783.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 861      -121.98     37.58                20.0       4126.0          1031.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = df[['latitude','longitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value']]
df
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 701       37.64    -121.97                32.0       1283.0           194.0
# 830       37.61    -121.99                 9.0       3666.0           711.0
# 859       37.57    -121.97                21.0       4342.0           783.0
# 860       37.58    -121.96                15.0       3575.0           597.0
# 861       37.58    -121.98                20.0       4126.0          1031.0
# ...         ...        ...                 ...          ...             ...
# 20635     39.48    -121.09                25.0       1665.0           374.0
# 20636     39.49    -121.21                18.0        697.0           150.0
# 20637     39.43    -121.22                17.0       2254.0           485.0
# 20638     39.43    -121.32                18.0       1860.0           409.0
# 20639     39.37    -121.24                16.0       2785.0           616.0
#
# ...

# %%
null_column = df.isna().sum()
null_column
# Out:
# latitude                0
# longitude               0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        157
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
#Q1: There's one feature with missing values. What is it?
#A1: total_bedrooms

# %%
#Q2: what is the median of variable 'population'?

print(df['population'].median())
# Out:
# 1195.0

# %%
plt.figure(figsize=(6,4))

sns.histplot(df.median_house_value, bins=40, color='black', alpha=1)
plt.ylabel('freq')
plt.xlabel('price')
plt.title('distribution of prices')

plt.show()

# %%
df['median_house_value_log'] = np.log1p(df['median_house_value'])
df
# Out:
#        latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 701       37.64    -121.97                32.0       1283.0           194.0
# 830       37.61    -121.99                 9.0       3666.0           711.0
# 859       37.57    -121.97                21.0       4342.0           783.0
# 860       37.58    -121.96                15.0       3575.0           597.0
# 861       37.58    -121.98                20.0       4126.0          1031.0
# ...         ...        ...                 ...          ...             ...
# 20635     39.48    -121.09                25.0       1665.0           374.0
# 20636     39.49    -121.21                18.0        697.0           150.0
# 20637     39.43    -121.22                17.0       2254.0           485.0
# 20638     39.43    -121.32                18.0       1860.0           409.0
# 20639     39.37    -121.24                16.0       2785.0           616.0
#
# ...

# %%
plt.figure(figsize=(6,4))

sns.histplot(df.median_house_value_log, bins=40, color='black', alpha=1)
plt.xlabel('log(price + 1))')
plt.ylabel('freq')
plt.title('distribution of prices after log transformation')

plt.show()

# %%
#df_0 = df
#df_0['total_bedrooms'] = df_0['total_bedrooms'].fillna(value=np.zeros)

# %%
# shuffle dataset
np.random.seed(42)

n = len(df)

n_val = int(0.2 * n)
n_test = int(0.2 * n)
n_train = n - (n_val + n_test)

idx = np.arange(n)
np.random.shuffle(idx)

df_shuffled = df.iloc[idx]

df_train = df_shuffled.iloc[:n_train].copy()
df_val = df_shuffled.iloc[n_train:n_train+n_val].copy()
df_test = df_shuffled.iloc[n_train+n_val:].copy()

# %%
y_train = df_train.median_house_value_log.values
y_val = df_val.median_house_value_log.values
y_test = df_test.median_house_value_log.values

df_train = df_train.drop(columns=['median_house_value','median_house_value_log'])
df_val = df_val.drop(columns=['median_house_value','median_house_value_log'])
df_test = df_test.drop(columns=['median_house_value','median_house_value_log'])

# %%
#linear regression
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    #XTX = X.T.dot(X)
    #XTX = np.matmul(X.T, X) 
    #XTX = X @ X.T
    XT = np.transpose(X)
    XTX = np.matmul(XT, X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)

    return w[0], w[1:]

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
#base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
#fill with 0

def prepare_X(df):
    df_num = df.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 2
#       1 X_train = prepare_X(df_train)
# ----> 2 w_0, w = train_linear_regression(X_train, y_train)
#
# Cell In[128], line 5, in train_linear_regression(X, y)
#       2 ones = np.ones(X.shape[0])
#       3 X = np.column_stack([ones, X])
# ----> 5 XTX = X.T.dot(X)
#       6 XTX_inv = np.linalg.inv(XTX)
#       7 w = XTX_inv.dot(X.T).dot(y)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'builtin_function_or_method'

# %%
y_pred = w_0 + X_train.dot(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 y_pred = w_0 + X_train.dot(w)
#
# NameError: name 'w_0' is not defined

# %%
plt.figure(figsize=(6,4))

sns.histplot(
